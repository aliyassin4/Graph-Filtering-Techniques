# %% [markdown]
# # Import Libraries

# %%
import community.community_louvain as community
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
import pandas as pd
import numpy as np
import math


import os, sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
    
from Utils.utils import shannon_entropy, extract_backbones_and_measures, extract_measures
from Backbones.high_salience_skeleton import high_salience_skeleton as hss
from Backbones.doubly_stochastic import read#, doubly_stochastic as ds
from Backbones.marginal_likelihood_filter import MLF
from Backbones import disparity_filter as disf
from Backbones import h_backbone as hb
#from Backbones import marginal_likelihood_filter as ml
from Backbones.noise_corrected import noise_corrected as nc
from Utils.portrait_divergence import portrait_divergence, portrait_divergence_weighted
# %matplotlib inline

# %% [markdown]
# # Import the network

# %% [raw]
# #create a bipartite projection
# network= 'senators'
#
# #read edge list from csv file
# edge_list = pd.read_csv('../Datasets/' + network + '.csv', index_col='name')
#
# g = edge_list.dot(edge_list.T)
# g.values[[np.arange(g.shape[0])]*2] = 0
#
# G = nx.from_pandas_adjacency(g)
# G = nx.from_numpy_matrix(g.values)
# label_mapping = {idx: val for idx, val in enumerate(g.columns)}
# G = nx.relabel_nodes(G, label_mapping)
# #nx.to_pandas_edgelist(G, source='source', target='target').to_csv('senators.csv', header=True, index=False)

# %%
#initialize the network name 
network= 'USairport_2010'

#read edge list from csv file
edge_list = pd.read_csv('../Datasets/' + network + '.csv')
edge_list.weight = edge_list.weight.astype(int)

#read edge list from csv file for the doubly stochastic filter, noice corrected and the high salience skeleton
table, nnodes, nnedges = read("../Datasets/" + network + '.csv', "weight", sep=',', consider_self_loops=False, triangular_input = True, undirected=True) 
table.weight = table.weight.astype(int)  

#create graph from the edge list
G = nx.from_pandas_edgelist(edge_list, edge_attr='weight', create_using=nx.Graph())
#top_10_labels = {name:name for name in pd.DataFrame(G.degree(weight='weight')).sort_values(by=1, ascending=False)[:15][0].to_numpy()}

#take only the largest connected component
largest_cc = max(nx.connected_components(G), key=len)
G = G.subgraph(largest_cc).copy()
        
original_measures = extract_measures(G)

# %% [markdown]
# # Extract the backbones

# %%
#initialize the fraction of nodes to be extracted
fractions = [0.02, 0.04, 0.06, 0.08, 0.1 , 0.12, 0.14, 0.16, 0.18, 0.2 , 0.22, 0.24, 0.25, 0.26, 0.28, 0.3 , 0.32, 0.34, 0.36, 0.38, 0.4, 0.5, 0.6, 0.7, 0.75, 0.8, 0.9, 1]

#initialize the dictionary that contains all backbones
all_backbones_graphs = dict()
all_backbones_measures = dict()

# %% [markdown]
# ## Global Threshold

# %%
#sort edges by weight
backbone = edge_list.copy()
backbone = backbone.sort_values(by='weight', ascending=False)
backbone['threshold'] = backbone['weight']


#extract different backbones with different network size and calculate the evaluation measures
backbones_dict, backbone_measures = extract_backbones_and_measures(G, backbone, fractions, 'Edges')

#add the backbone graphs and measures to the all backbones dictionary
all_backbones_graphs['Global Threshold'] = backbones_dict
all_backbones_measures['Global Threshold'] = backbone_measures

# %% [markdown]
# ## The Disparity Filter Backbone

# %%
#apply the disparity filter algorithm
backbone = disf.disparity_filter(G)

#convert the graph to a dataframe for processing and sort the values by the alpha value
df_backbone = nx.to_pandas_edgelist(backbone)
df_backbone = df_backbone.rename(columns={'alpha': 'threshold'})
df_backbone = df_backbone.sort_values(by='threshold')

#extract different backbones with different network size and calculate the evaluation measures
backbones_dict, backbone_measures = extract_backbones_and_measures(G, df_backbone, fractions, 'Edges')

#add the backbone graphs and measures to the all backbones dictionary
all_backbones_graphs['Disparity Filter'] = backbones_dict
all_backbones_measures['Disparity Filter'] = backbone_measures

# %% [markdown]
# ## The High Saleince Skeleton

# %%
#apply the high salience skeleton algorithm
hss_backbone = hss(table, return_self_loops=False, undirected=True)
    
#sort score values of the edges
hss_backbone = hss_backbone.rename(columns={'score': 'threshold'})
hss_backbone = hss_backbone.sort_values(by='threshold', ascending=False)

#extract different backbones with different network size and calculate the evaluation measures
backbones_dict, backbone_measures = extract_backbones_and_measures(G, hss_backbone, fractions, 'Edges')

#add the backbone graphs and measures to the all backbones dictionary
all_backbones_graphs['High Salience Skeleton'] = backbones_dict
all_backbones_measures['High Salience Skeleton'] = backbone_measures

# %% [markdown]
# ## The Doubly Stochastic Filter

# %% [raw]
# #apply the doubly stochastic filter
# ds_backbone = ds(table, undirected = True, return_self_loops = False)
#
# #sort score values of the edges
# ds_backbone = ds_backbone.rename(columns={'score': 'threshold'})
# ds_backbone = ds_backbone.sort_values(by='threshold', ascending=False)
#
#
# #extract different backbones with different network size and calculate the evaluation measures
# backbones_dict, backbone_measures = extract_backbones_and_measures(G, ds_backbone, fractions, 'Edges')
#
# #add the backbone graphs and measures to the all backbones dictionary
# all_backbones_graphs['Doubly Stochastic Filter'] = backbones_dict
# all_backbones_measures['Doubly Stochastic Filter'] = backbone_measures

# %% [markdown]
# # Marginal Likelihood Filter

# %%
# Apply the transformer to the edgelist
mlf = MLF(directed=False)
mlf_backbone = mlf.fit_transform(edge_list)

#sort score values of the edges
mlf_backbone = mlf_backbone.rename(columns={'significance': 'threshold'})
mlf_backbone = mlf_backbone.sort_values(by='threshold', ascending=False)

#extract different backbones with different network size and calculate the evaluation measures
backbones_dict, backbone_measures = extract_backbones_and_measures(G, mlf_backbone, fractions, 'Edges')

#fix thresholds since they are transformed to log values in the extraction function
backbone_measures['threshold'] = [np.exp(-threshold) for threshold in backbone_measures['threshold']]

#add the backbone graphs and measures to the all backbones dictionary
all_backbones_graphs['Marginal Likelihood Filter'] = backbones_dict
all_backbones_measures['Marginal Likelihood Filter'] = backbone_measures

# %% [markdown]
# # Noise Corrected Filter

# %%
#apply the noise corrected filter
nc_backbone = nc(table, undirected = True, return_self_loops = False, calculate_p_value = False)
nc_backbone['threshold'] = nc_backbone["score"] - (1 * nc_backbone["sdev_cij"])

#sort score values of the edges and take only positive values
nc_backbone = nc_backbone.sort_values(by='threshold', ascending=False)

#extract different backbones with different network size and calculate the evaluation measures
backbones_dict, backbone_measures = extract_backbones_and_measures(G, nc_backbone, fractions, 'Edges')

#add the backbone graphs and measures to the all backbones dictionary
all_backbones_graphs['Noise Corrected Filter'] = backbones_dict
all_backbones_measures['Noise Corrected Filter'] = backbone_measures

# %% [markdown]
# ## The Polya Filter

# %%
#read edge list from csv file
pf_backbone = pd.read_csv('../Results/Backbones Results/PF/' + network + '.csv')

#sort score values of the edges
pf_backbone = pf_backbone.rename(columns={'p_values': 'threshold'})
pf_backbone = pf_backbone.sort_values(by='threshold')

#extract different backbones with different network size and calculate the evaluation measures
backbones_dict, backbone_measures = extract_backbones_and_measures(G, pf_backbone, fractions, 'Edges')

#add the backbone graphs and measures to the all backbones dictionary
all_backbones_graphs['Polya Filter'] = backbones_dict
all_backbones_measures['Polya Filter'] = backbone_measures

# %% [markdown]
# ## Gloss

# %% [raw]
# #how to run
# #input edge list file formated i j w. i and j are numbers.
# #input 1 for undirected network and 2 for directed
# !../Backbones/gloss_backbone.o ../Datasets/edge_list.csv 1

# %%
#read edge list from csv file
gloss_backbone = pd.read_csv('../Results/Backbones Results/GLOSS/' + network + '.csv', names=['source', 'target', 'threshold', 'weight'], sep=' ')
labels = pd.read_csv('../Datasets/' + network + '_labels.csv', index_col='index')

#relabel using saved labels
labels = labels.T.to_dict('list')
gloss_backbone['source'] = gloss_backbone['source'].replace(labels)
gloss_backbone['target'] = gloss_backbone['target'].replace(labels)

#sort score values of the edges
gloss_backbone = gloss_backbone.sort_values(by='threshold')

#extract different backbones with different network size and calculate the evaluation measures
backbones_dict, backbone_measures = extract_backbones_and_measures(G, gloss_backbone, fractions, 'Edges')

#add the backbone graphs and measures to the all backbones dictionary
all_backbones_graphs['GLOSS Filter'] = backbones_dict
all_backbones_measures['GLOSS Filter'] = backbone_measures

# %% [markdown]
# ## Lans

# %% [raw]
# #run in python2.7 environment
# import pandas as pd
# import networkx as nx
#
# network = 'lesmis'
# #read edge list from csv file
# #edge_list = pd.read_csv('../Datasets/' + network + '_unlabeled.csv', names=['source', 'target', 'weight'], sep=' ')
#
# G = nx.read_weighted_edgelist('../Datasets/' + network + '_unlabeled.csv', delimiter=' ')
# #create graph from the edge list
# #G = nx.from_pandas_edgelist(edge_list, edge_attr='weight')#, create_using=nx.Graph())
# G = nx.to_numpy_matrix(G)

# %% [raw]
# import sys
# import numpy as np
# sys.path.append('/Users/ali/Desktop/Code/Graph-Filtering-Techniques/Backbones')
# import lans_backbone
#
# #calulate the backbone and save it in csv file
# la_backbone = lans_backbone.lans_backbone(np.asmatrix(G))
# la_backbone.to_csv('../Results/Backbones Results/LANS/t' + network + '.csv', index=False)

# %% [raw]
# #read edge list from csv file
# lans_backbone = pd.read_csv('../Results/Backbones Results/LANS/' + network + '.csv')
#
# labels = pd.read_csv('../Datasets/' + network + '_labels.csv', index_col='index')
#
# #relabel using saved labels
# labels = labels.T.to_dict('list')
# lans_backbone['source'] = lans_backbone['source'].replace(labels)
# lans_backbone['target'] = lans_backbone['target'].replace(labels)
#
# #sort score values of the edges
# lans_backbone = lans_backbone.rename(columns={'weight': 'threshold'})
# lans_backbone = lans_backbone.sort_values(by='threshold')
#
# #add weights
# weights = []
# for i in range(lans_backbone.shape[0]):
#     u = lans_backbone.loc[i]['source']
#     v = lans_backbone.loc[i]['target']
#     weights.append(G[u][v]['weight'])
# lans_backbone['weight'] = weights
#
#
# #extract different backbones with different network size and calculate the evaluation measures
# backbones_dict, backbone_measures = extract_backbones_and_measures(G, lans_backbone, fractions, 'Edges')
#
# #add the backbone graphs and measures to the all backbones dictionary
# all_backbones_graphs['LANS Filter'] = backbones_dict
# all_backbones_measures['LANS Filter'] = backbone_measures

# %% [markdown]
# ## Recast

# %% [raw]
# #need java 1.7 or higher., python 2.7 and two configuration files for java and python
# #edit both config files
# #run make

# %% [markdown]
# # Normal Backbone

# %%
def calculate_z_scores(node, G, border):
    #extract the second neighborhood of the given node
    g = nx.Graph()
    for neighbor in G.neighbors(node):
        g.add_edge(node, neighbor,weight=G[node][neighbor]['weight'])
        for nneighbor in G.neighbors(neighbor):
            g.add_edge(nneighbor, neighbor,weight=G[nneighbor][neighbor]['weight'])

    #extract all the weight of the second neighborhood
    neighbourhood_weights = list(nx.get_edge_attributes(g, 'weight').values())

    #duplicate the edges when reaching the border
    if G.degree(node) <= border:
        #print(neighbourhood_weights)
        neighbourhood_weights = neighbourhood_weights*2
        #print(neighbourhood_weights)
        
        
    #calculate mean of the weights in the second neighbourhood
    mean = np.mean(neighbourhood_weights)

    #calculate standard deviation of the weights in the second neighbourhood
    stdv = np.std(neighbourhood_weights)

    #loop through the edges of the node and assign the z-scores
    for u,v,weight in g.edges(data='weight'):
        z_score = (weight - mean) / stdv
        if 'z_score'in G[u][v]:
            G[u][v]['z_score'] = max(G[u][v]['z_score'], z_score)
        else:
            G[u][v]['z_score'] = z_score

# %%
len(G)
# Out:
# 1572

# %%
len(G.edges())
# Out:
# 17214

# %%
GG = G.copy()
border = 1
for node in GG.nodes():
    calculate_z_scores(node, GG, border)

# %%
z_score_backbone = nx.to_pandas_edgelist(GG)

#sort score values of the edges
z_score_backbone = z_score_backbone.rename(columns={'z_score': 'threshold'})
z_score_backbone = z_score_backbone.sort_values(by='threshold', ascending=False)

# %%
#extract different backbones with different network size and calculate the evaluation measures
backbones_dict, backbone_measures = extract_backbones_and_measures(G, z_score_backbone, fractions, 'Edges')

#add the backbone graphs and measures to the all backbones dictionary
all_backbones_graphs['Z-score Filter'] = backbones_dict
all_backbones_measures['Z-score Filter'] = backbone_measures

# %% [markdown]
# ## Tribe

# %%
from scipy import stats

# %%
g = G.copy()

for u, v, w in g.edges(data='weight'):
    #print(u,v, w)
    G[u][v]['df'] = df_backbone[((df_backbone['source'] == u) & (df_backbone['target'] == v)) | ((df_backbone['source'] == v) & (df_backbone['target'] == u))]['threshold'].iloc[-1]
    G[u][v]['zscore'] = z_score_backbone[((z_score_backbone['source'] == u) & (z_score_backbone['target'] == v)) | ((z_score_backbone['source'] == v) & (z_score_backbone['target'] == u))]['threshold'].iloc[-1]
    G[u][v]['hss'] = hss_backbone[((hss_backbone['source'] == u) & (hss_backbone['target'] == v)) | ((hss_backbone['source'] == v) & (hss_backbone['target'] == u))]['threshold'].iloc[-1]
    G[u][v]['mlf'] = mlf_backbone[((mlf_backbone['source'] == u) & (mlf_backbone['target'] == v)) | ((mlf_backbone['source'] == v) & (mlf_backbone['target'] == u))]['threshold'].iloc[-1]
    G[u][v]['nc'] = nc_backbone[((nc_backbone['source'] == u) & (nc_backbone['target'] == v)) | ((nc_backbone['source'] == v) & (nc_backbone['target'] == u))]['threshold'].iloc[-1]
    G[u][v]['pf'] = pf_backbone[((pf_backbone['source'] == u) & (pf_backbone['target'] == v)) | ((pf_backbone['source'] == v) & (pf_backbone['target'] == u))]['threshold'].iloc[-1]

# %%
df = nx.to_pandas_edgelist(g)
#dd = df.reindex(columns=['source', 'target', 'weight', 'zscore', 'disparity'])
#dd.sort_values(by='weight', ascending=False)[:10]

# %%
df = df.drop(columns=['source', 'target'])

# %%
df = df.sort_values(by='weight', ascending=False)

# %%
corr = pd.DataFrame(columns=df.columns, index=df.columns)

# %%
for col1 in df.columns:
    for col2 in df.columns:
        corr[col1][col2] = stats.spearmanr(df[col1], df[col2])[0]

# %%
stats.spearmanr(df['df'], df['hss'])
# Out:
# SpearmanrResult(correlation=-0.36813786483702404, pvalue=0.0)

# %%
corr
# Out:
#               df    zscore    weight       mlf        pf       hss   nc
# df           1.0 -0.633542 -0.762671 -0.713424 -0.025421 -0.368138  NaN
# zscore -0.633542       1.0  0.490565   0.55721  0.031085  0.258292  NaN
# weight -0.762671  0.490565       1.0  0.421076 -0.004104  0.214144  NaN
# mlf    -0.713424   0.55721  0.421076       1.0  0.040759   0.40979  NaN
# pf     -0.025421  0.031085 -0.004104  0.040759       1.0  0.026258  NaN
# hss    -0.368138  0.258292  0.214144   0.40979  0.026258       1.0  NaN
# nc           NaN       NaN       NaN       NaN       NaN       NaN  NaN

# %% [raw]
# from scipy import stats
#
# l1 = z_score_backbone.sort_values(by='weight', ascending=False)['threshold'].to_list()#[:10]
# l2 = backbone.sort_values(by='weight', ascending=False)['threshold'].to_list()#[:10]
#
# stats.spearmanr(l1, l2)[0]

# %% [raw]
# l1 = z_score_backbone.sort_values(by='weight', ascending=False)['threshold'].to_list()#[:10]
# l2 = df_backbone.sort_values(by='weight', ascending=False)['threshold'].to_list()#[:10]
#
# stats.spearmanr(l1, l2)

# %%
sns.set_theme()

# %% [raw]
# import matplotlib.pyplot as plt
# plt.figure(figsize=(10,10))
# z = nx.from_pandas_edgelist(z_score_backbone.sort_values(by='threshold', ascending=False)[:10])
# nx.draw_networkx(z, pos=nx.spring_layout(G,seed=2))

# %% [raw]
# import matplotlib.pyplot as plt
# plt.figure(figsize=(10,10))
# zz = nx.from_pandas_edgelist(df_backbone.sort_values(by='threshold')[:10])
# nx.draw_networkx(zz, pos=nx.spring_layout(G,seed=2))

# %% [raw]
# import matplotlib.pyplot as plt
# plt.figure(figsize=(10,10))
# zzz = nx.from_pandas_edgelist(backbone.sort_values(by='threshold', ascending=False)[:10])
# nx.draw_networkx(zzz, pos=nx.spring_layout(G,seed=2))

# %% [markdown]
# ## The h-Backbone

# %% [markdown]
# #apply the h-backbone  algorithm and add the h-bridge and h-weight values to the dictionary
# h_bridge, h_weight, backbone = hb.h_backbone(G)
#
# #create an edge list from the result graph with the scores
# h_backbone = nx.to_pandas_edgelist(backbone)

# %% [markdown]
# ## Zakaria

# %% [markdown]
# ## Stephany

# %% [raw]
# from Backbones import modularity_backbone as modv
#
# unlabeled_edge_list = pd.read_csv('../Datasets/karate.csv', sep=' ')
# g = nx.from_pandas_edgelist(unlabeled_edge_list, edge_attr='weight', create_using=nx.Graph())
#
# k_nodes_to_remove = round(len(g.nodes())*0.7)
# backbone, Q1, Q2, Q31, Q32 = modv.modularity_backbone(G, k_nodes_to_remove)

# %% [markdown]
# # Plot and compare the measures

# %%
sns.set_theme()
from textwrap import wrap

row = 3
measures = list(all_backbones_measures['Global Threshold'].columns)
measures.remove('threshold')
col = math.ceil(len(all_backbones_measures['Disparity Filter'].columns)/row)
fig, axs = plt.subplots(col, row, figsize=(15,35))


for i, measure in enumerate(measures):
    #i = i+s
    for backbone in all_backbones_measures:
        b = all_backbones_measures[backbone]
        if measure == 'average_components_size' or measure == 'weighted_modularity' or measure =='diameter':
            s= s+1
            #axs[int(i/row), i%row].errorbar(fractions, [b[measure][fraction][0] for fraction in fractions], yerr=[b[measure][fraction][1] for fraction in fractions], label=backbone, marker='o', markersize=3)
            #axs[int(i/row), i%row].plot(fractions, [b[measure][fraction][0] for fraction in fractions], label=backbone, marker='o', markersize=3)

        else:
            axs[int(i/row), i%row].plot(fractions, b[measure], label=backbone, marker='o', markersize=3)
        axs[int(i/row), i%row].set_ylabel(measure, fontsize=18)
    if measure != 'average_components_size' or measure == 'weighted_modularity' or measure =='diameter':
        #axs[int(i/row), i%row].axhline(y=original_measures[measure], color='black', linestyle='--', label='Original Network')
        s=1


plt.setp(axs[-1, :], xlabel='Fraction of Nodes Preserved')#, labelsize=20)
fig.suptitle('Evaluation Measures for the ' + network +' Network', fontsize=25);

for ax in axs.reshape(-1):
    ax.tick_params(axis='x', labelsize=15)
    ax.tick_params(axis='y', labelsize=15)
    #ax.set_xticklabels(fractions)
    ax.grid(True)
    
    
handles, labels = axs[0,1].get_legend_handles_labels()
labels = [ '\n'.join(wrap(l, 20)) for l in labels]
lg = fig.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5), fontsize=35)
 
# lg = fig.legend(handles, labels, bbox_to_anchor=(0.5, -0.05), fontsize=25, ncol=8)

for line in lg.get_lines():
    line.set_linewidth(6)

plt.tight_layout(rect=[0, 0.03, 1, 0.98])

#plt.savefig('../Results/Figures/All/Topological/' + network + '.png')

# %% [raw]
# weighted_degree = list(dict(all_backbones_graphs['Global Threshold'][0.2].degree(weight='weight')).values())

# %% [raw]
# from collections import Counter
# from operator import itemgetter
# import matplotlib.pyplot as plt
#
# # G = some networkx graph
# fraction=0.3
# degree_sequence = sorted((d for n, d in G.degree()), reverse=True)
#
# plt.figure(1)
#
# # # prep axes
# # plt.xlabel('degree')
# # plt.xscale('log')
# # plt.xlim(0, max(x))
#
# # plt.ylabel('frequency')
# # plt.yscale('log')
# # plt.ylim(0, max(y)+1)
# #                                                                                                                                      # do plot
# # plt.scatter(x, y, marker='.', color='black', label='original')
#
# d=[]
# for backbone in all_backbones_graphs.keys():
#     b = all_backbones_graphs[backbone][fraction]
#     degrees = list(dict(b.degree()).values())
# #     degree_counts = Counter(degrees)
# #     x, y = zip(*degree_counts.items())
# #     plt.scatter(x, y, marker='.', label='backbone')
# # plt.bar(*np.unique(degree_sequence, return_counts=True))
#     d.append(degrees)
# sns.displot(data=d, kind='kde', legend=False)
#
#
#
# #sns.displot(data=degree_sequence, kind='kde')
# # plt.title("Degree histogram")
# # plt.xlabel("Degree")
# # plt.ylabel("# of Nodes")
# plt.legend(labels=all_backbones_graphs.keys())
#
#
#
#
# plt.show()

# %% [raw]
# quartiles = [0.25, 0.5, 0.75, 1]
# quart = 0.7
#
# data = []
# plt.figure(figsize=(10, 5))
# for method in all_backbones_graphs.keys():
#     #for quart in quartiles:
#     backbone = all_backbones_graphs[method][quart]
#     #data.append(list(dict(backbone.degree()).values()))
#     data.append(list(nx.get_edge_attributes(backbone, 'weight').values()))
# sns.violinplot(data=data)
# plt.xticks(range(len(all_backbones_graphs.keys())), all_backbones_graphs.keys(), rotation=8)
# plt.title('Weight distribution for quartile=' + str(quart))
#
#
# plt.tight_layout()

# %% [raw]
# # example of calculating the kl divergence (relative entropy) with scipy
# from scipy.special import rel_entr
# # define distributions
# p = [0.10, 0.40, 0.50]
# q = [0.80, 0.15, 0.05]
# # calculate (P || Q)
# kl_pq = rel_entr(G_degrees, g_degrees)
# print('KL(P || Q): %.3f nats' % sum(kl_pq))
# # calculate (Q || P)
# kl_qp = rel_entr(q, p)
# print('KL(Q || P): %.3f nats' % sum(kl_qp))

# %% [raw]
# #fraction=0.5
# pos = nx.circular_layout(G)
#
# important_labels = ['Valjean', 'Cosette', 'Javert', 'Myriel', 'Thenardier', 'Fantine', 'Pontmercy', 'Gavroche', 'Marius']
#
# labels = {}
# for node in G.nodes():
#     if node in important_labels:
#         #set the node name as the key and the label as its value
#         labels[node] = node

# %% [raw]
# sns.reset_orig()
#
#
# plt.figure(1)
#
# # prep axes
# plt.xlabel('degree')
# plt.xscale('log')
# #plt.xlim(1, max(x))
#
# plt.ylabel('degree distribution')
# plt.yscale('log')
# #plt.ylim(1, max(y))
#                                                                                                                                      # do plot
# sns.scatterplot(degree_counts.keys(), degree_counts.values(), marker='.', s=100)#, size_norm=True)
# plt.show()

# %% [raw]
# fraction = 0.3

# %% [raw]
# sns.reset_orig()
#
# degrees = G.degree()
# nodes = G.nodes()
# n_color = np.asarray([degrees[n] for n in nodes])
#
# row = 2
# col = math.ceil(len(all_backbones_graphs.keys())/row)
#
#
# fig, axs = plt.subplots(col, row, figsize=(12,20))
#
# for i, backbone in enumerate(all_backbones_graphs):
#     b = all_backbones_graphs[backbone][fraction]
#     filtered_edges = [edge for edge in G.edges() if edge not in b.edges()]
#     filtered_edges_width = [round((G[u][v]['weight']*len(G.nodes())*3)/edge_list['weight'].sum(),3) for u,v in filtered_edges]
#     backbone_edges_width = [round((G[u][v]['weight']*len(G.nodes())*3)/edge_list['weight'].sum(),3) for u,v in b.edges()]
#
#     nc = nx.draw_networkx_nodes(G, pos, ax=axs[int(i/row), i%row], node_color=n_color, cmap='viridis_r', node_size=50)
#     nx.draw_networkx_edges(G, pos, edgelist=filtered_edges, width= filtered_edges_width,ax=axs[int(i/row), i%row], edge_color='silver', alpha=0.8)
#     nx.draw_networkx_edges(G, pos, edgelist=b.edges(), ax=axs[int(i/row), i%row], edge_color='crimson', width=backbone_edges_width, alpha=0.8)
#
# #     label_pos = {}
# #     keys = pos.keys()
# #     for ind, key in enumerate(keys):
# #         if ind/len(keys) < 0.5:
# #             label_pos[key] = (pos[key][0], pos[key][1]+0.1)
# #         else:
# #             label_pos[key] = (pos[key][0], pos[key][1]-0.15)
#     #nx.draw_networkx_labels(G, label_pos, labels=top_10_labels, font_size=8, ax=axs[int(i/row), i%row], font_family="sans-serif", horizontalalignment='center', verticalalignment='bottom')
#
#
#
#     axs[int(i/row),i%row].set_title(backbone, fontsize=18)
#
# for ax in axs.reshape(-1):
#     plt.colorbar(nc, ax=ax)
# plt.tight_layout()

# %% [raw]
# sns.reset_orig()
#
# colors = ['#332288', '#88CCEE', '#44AA99', '#117733', '#999933', '#DDCC77', '#CC6677', '#882255', '#AA4499']
# degrees = G.degree()
# nodes = G.nodes()
# n_color = np.asarray([degrees[n] for n in nodes])
#
# row = 2
# col = math.ceil(len(all_backbones_graphs.keys())/row)*2
#
#
# #pos = nx.circular_layout(G)
# fig, axs = plt.subplots(col, row, figsize=(12,40))
#
# j=-1
# for i, backbone in enumerate(all_backbones_graphs):
#
#     i=j+1
#     b = all_backbones_graphs[backbone][fraction]
#
#     all_components = [b.subgraph(c).copy() for c in sorted(nx.connected_components(b), key=len, reverse=True)]
#
#     largest_cc = all_components[0]
#
#
#     #filtered_edges = [edge for edge in G.edges() if edge not in b.edges()]
#     backbone_edges_width = [round((G[u][v]['weight']*len(G.nodes())*1.5)/edge_list['weight'].sum(),3) for u,v in largest_cc.edges()]
#
#     nc = nx.draw_networkx_nodes(G, pos, ax=axs[int(i/row), i%row], node_size=50, node_color=n_color, cmap='viridis_r')
#     nx.draw_networkx_edges(G, pos, edgelist=largest_cc.edges(), ax=axs[int(i/row), i%row], edge_color='crimson', width=backbone_edges_width, alpha=0.8)
#
#     nx.draw_networkx_labels(G, pos, labels=labels, font_size=8, ax=axs[int(i/row), i%row], font_family="sans-serif", horizontalalignment='center', verticalalignment='bottom')
#
#
# #     nc = nx.draw_networkx_nodes(largest_cc, pos, ax=axs[int(i/row), i%row], node_size=50)#, node_color=[n_color[list(G.nodes()).index(node)] for node in largest_cc.nodes()], cmap='viridis')
# #     nx.draw_networkx_edges(largest_cc, pos, edgelist=largest_cc.edges(), ax=axs[int(i/row), i%row], edge_color='crimson', width=backbone_edges_width, alpha=0.8)
#
#     axs[int(i/row),i%row].set_title(backbone, fontsize=18)
#
#
#     j = i+1
#     for index, component in enumerate(all_components[1:]):
#         backbone_edges_width = [round((G[u][v]['weight']*len(G.nodes())*1.5)/edge_list['weight'].sum(),3) for u,v in component.edges()]
#         nc = nx.draw_networkx_nodes(G, pos, ax=axs[int(j/row), j%row], node_size=50, node_color=n_color, cmap='viridis_r')
#         nx.draw_networkx_edges(G, pos, edgelist=component.edges(), ax=axs[int(j/row), j%row], edge_color=colors[index], alpha=0.8)#width=backbone_edges_width,
#
# #         nc = nx.draw_networkx_nodes(component, pos, ax=axs[int(j/row), j%row], node_size=50)#, node_color=[n_color[list(G.nodes()).index(node)] for node in component.nodes()], cmap='viridis')
# #         nx.draw_networkx_edges(component, pos, edgelist=component.edges(), ax=axs[int(j/row), j%row], edge_color='crimson', width=backbone_edges_width, alpha=0.8)
#
#         #nx.draw_networkx_labels(G, pos, labels=labels, font_size=8, ax=axs[int(j/row), j%row], font_family="sans-serif", horizontalalignment='center', verticalalignment='bottom')
#
#     axs[int(j/row),j%row].set_title(backbone, fontsize=18)
#
#     #break
#
# for ax in axs.reshape(-1):
#     plt.colorbar(nc, ax=ax)#, ticks=[0, 5, 10, 15, 20, 25, 30, 35])
# plt.tight_layout()

# %% [raw]
# #portrait_divergence can be used for weighted and unweighted networks
# #distance between zero and one
#
# import itertools
# from Utils.portrait_divergence import portrait_divergence, portrait_divergence_weighted
#
# Djs_net1_net1 = portrait_divergence(net1, net2)
# Djs_net1_net2 = portrait_divergence_weighted(net1, net2)
#
# print(Djs_net1_net1)
# print(Djs_net1_net2)

# %% [raw]
# # For Laplacian Spectra used for unweighted networks:
#
# import networkx as nx
# import math
#
# _net1 = nx.laplacian_spectrum(net1)
# _net2 = nx.laplacian_spectrum(net2)
#
# Djs_net1_net2 = math.sqrt(sum([(a - b) ** 2 for a, b in zip(_net1, _net2)]))
# print(Djs_net1_net2)

# %% [raw]
# #NetLSD
# from Utils.netlsd import heat, compare
#
# import networkx as nx
# import numpy as np
#
# _net1 = heat(net1)
# _net2 = heat(net2)
#
# distance_net1_net2 = compare(_net1, _net1)
#
# print("distance_net1_net2", distance_net1_net2)

# %% [raw]
# fraction=1
# methods = all_backbones_graphs.keys()
# portrait_distance = pd.DataFrame(columns=list(methods)+['Original'], index=list(methods)+['Original'], dtype='float')
#
# for backbone1 in methods:
#     b = all_backbones_graphs[backbone1][fraction]
#     all_components = [b.subgraph(c).copy() for c in sorted(nx.connected_components(b), key=len, reverse=True)]
#     net1 = all_components[0]
#     for backbone2 in methods:
#         b = all_backbones_graphs[backbone2][fraction]
#         all_components = [b.subgraph(c).copy() for c in sorted(nx.connected_components(b), key=len, reverse=True)]
#         net2 = all_components[0]
#
#         portrait_distance[backbone1][backbone2] = portrait_divergence(net1, net2)
#
# for backbone in methods:
#     b = all_backbones_graphs[backbone1][fraction]
#     all_components = [b.subgraph(c).copy() for c in sorted(nx.connected_components(b), key=len, reverse=True)]
#     net1 = all_components[0]
#
#     net2 = G
#     portrait_distance[backbone]['Original'] = portrait_distance['Original'][backbone] = portrait_divergence(net1, net2)
#
# fig, ax = plt.subplots(figsize=(8, 7))
#
# mask = np.zeros_like(portrait_distance)
# mask[np.triu_indices_from(mask)] = 1
# plt.title("Unweighted Portrait Distance Between Backbones for "+ str(int(fraction*100))+" of Edges", fontsize = 12, weight="bold")
# sns.heatmap(portrait_distance, mask= mask, ax= ax, annot= True, vmin=0, vmax=1, cmap='Blues')
# plt.tight_layout()

# %% [raw]
# methods = all_backbones_graphs.keys()
# portrait_distance = pd.DataFrame(columns=list(methods)+['Original'], index=list(methods)+['Original'], dtype='float')
#
# for backbone1 in methods:
#     b = all_backbones_graphs[backbone1][fraction]
#     all_components = [b.subgraph(c).copy() for c in sorted(nx.connected_components(b), key=len, reverse=True)]
#     net1 = all_components[0]
#     for backbone2 in methods:
#         b = all_backbones_graphs[backbone2][fraction]
#         all_components = [b.subgraph(c).copy() for c in sorted(nx.connected_components(b), key=len, reverse=True)]
#         net2 = all_components[0]
#
#         portrait_distance[backbone1][backbone2] = portrait_divergence_weighted(net1, net2)
#
# for backbone in methods:
#     b = all_backbones_graphs[backbone1][fraction]
#     all_components = [b.subgraph(c).copy() for c in sorted(nx.connected_components(b), key=len, reverse=True)]
#     net1 = all_components[0]
#
#     net2 = G
#     portrait_distance[backbone]['Original'] = portrait_distance['Original'][backbone] = portrait_divergence_weighted(net1, net2)
#
# fig, ax = plt.subplots(figsize=(8, 7))
#
# mask = np.zeros_like(portrait_distance)
# mask[np.triu_indices_from(mask)] = 1
# plt.title("Weighted Portrait Distance Between Backbones for "+ str(int(fraction*100))+" of Edges", fontsize = 12, weight="bold")
# sns.heatmap(portrait_distance, mask= mask, ax= ax, annot= True, vmin=0, vmax=1, cmap='Blues')
# plt.tight_layout()

# %% [markdown]
# ## SIR Analysis

# %% [raw]
# # importing libraries
# import math
#
# # Get the angles from 0 to 2 pie (360 degree) in narray object
# X = results['infection_participation']
#
# # Using built-in trigonometric function we can directly plot
# # the given cosine wave for the given angles
# Y1 = results['df_score']
# Y2 = results['hss_score']
#
# # Initialise the subplot function using number of rows and columns
# figure, axis = plt.subplots(1, 2, figsize=(10,4))
#
# # For Sine Function
# axis[0].scatter(X, Y1, label= "stars", color= "green", marker= "*")#, s=30)
#
# # x-axis label
# axis[0].set_xlabel('Infection Participation')
#
# # frequency label
# axis[0].set_ylabel('Disparity Filter score')
# axis[0].set_yticks(np.linspace(0,1,11))
#
#
#
# # For Cosine Function
# axis[1].scatter(X, Y2, label= "stars", color= "green", marker= "*")#, s=30)
#
# # x-axis label
# axis[1].set_xlabel('Infection Participation')
# axis[1].set_yticks(np.linspace(0,1,11))
#
# # frequency label
# axis[1].set_ylabel('High Salience Score')
#
# #figure.suptitle('Pearson Correlation')
#
# figure.tight_layout()
#
# # Combine all the operations and display
# plt.show()

# %%
# Import those libraries
from scipy.stats import pearsonr

# Import the sir simulations results
sir_results = pd.read_csv("../Results/Epidemic Simulations Resutls/" +network+ ".csv")

# Select the backbones with all the edges of the network
full_backbones = {backbone:all_backbones_graphs[backbone][1] for backbone in all_backbones_graphs.keys()}

#initialize the correlation dataframe
df = pd.DataFrame(columns=full_backbones.keys(), index=['infection_participation'])

#add the infection participation to the backbone graphs
for backbone in full_backbones:
    b = full_backbones[backbone]
    for u, v in b.edges():
        b[u][v]['infection_participation'] = sir_results[((sir_results['source'] == u) & (sir_results['target'] == v)) | ((sir_results['source'] == v) & (sir_results['target'] == u))]['infection_participation'].iloc[0]

    df_backbone = nx.to_pandas_edgelist(b)
    backbone_scores = df_backbone['threshold']
    sir_scores = df_backbone['infection_participation']
    df[backbone] = [pearsonr(backbone_scores, sir_scores)[0]]

# %%
df = df.T
#df['infection_participation'] = df['infection_participation'].abs()
df.sort_values(by='infection_participation', ascending=False)
df.to_csv('../Results/Figures/All/Diffusion/'+network+'.csv')

# %%
df

# %% [raw]
# comparison = pd.DataFrame()
# for backbone in full_backbones:
#     #print(full_backbones[backbone].edges(data=True))
#     b = nx.to_pandas_edgelist(full_backbones[backbone])
#     if backbone in ['Naive Threshold', 'High Salience Skeleton', 'Marginal Likelihood Filter']:
#         b = b.sort_values(by='threshold', ascending=False)
#     else:
#         b = b.sort_values(by='threshold')
#
#     #comparison[backbone] = b['source'] + '-' + b['target']
#     #comparison[:].to_csv('comp.csv')

# %% [raw]
# comparison = G.copy()
#
# for u, v in comparison.edges():
#     for backbone in full_backbones:
#         b = full_backbones[backbone]
#         comparison[u][v][backbone] = b[u][v]['threshold']
#
# nx.to_pandas_edgelist(comparison).to_csv('../Gephi Analysis/lesmis_all_backbones.csv', index=False)

# %% [raw]
# g  = all_backbones_graphs['Noise Corrected'][0.04]

# %% [raw]
# component_sizes = []
# for component in nx.connected_components(g):
#     comp = g.subgraph(component).copy()
#     component_sizes.append(len(comp))
# np.average(component_sizes)
# np.var(component_sizes)
